# %%
import logging
import joblib
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd


logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
df = pd.read_csv("../data/datasets/lead_prepared_global.csv")

# %%
df.columns
# Out:
# Index(['refid', 'name', 'date_entered_year', 'date_entered_month',
#        'date_entered_day', 'date_modified_year', 'date_modified_month',
#        'date_modified_day', 'converted', 'dernier_appel_year',
#        ...
#        'verbatim_192', 'verbatim_193', 'verbatim_194', 'verbatim_195',
#        'verbatim_196', 'verbatim_197', 'verbatim_198', 'verbatim_199',
#        'status_MQL', 'status_Nurterring'],
#       dtype='object', length=237)

# %%
verbatim_cols = list(filter(lambda x: 'verbatim' in x, df.columns))
status_cols = list(filter(lambda x: 'status' in x, df.columns))
description_cols = list(filter(lambda x: 'description' in x, df.columns))
other_cols = ['date_entered_year', 'date_entered_month', 'date_entered_day', 'date_modified_year', 'date_modified_month', 'date_modified_day','dernier_appel_year',
   'dernier_appel_year' ,'dernier_appel_month','dernier_appel_day' ,'duree_appel_minutes','duree_appel_heures','nb_appel','dernier_rdv_year','dernier_rdv_month','dernier_rdv_day' ,'duree_rdv_minutes','duree_rdv_heures','nb_rdv'   ]
converted = ['converted']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.subplots(figsize=(16,16))

corr = df[verbatim_cols + converted].corr()
heatmap = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu")
heatmap.figure.savefig("lead_corr_matrix_verbatim_converted.png")

# %%
plt.subplots(figsize=(16,16))

corr = df[description_cols + converted].corr()
heatmap = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu")
heatmap.figure.savefig("lead_corr_matrix_description_converted.png")

# %%
plt.subplots(figsize=(16,16))

corr = df[status_cols + converted].corr()
heatmap = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu")
heatmap.figure.savefig("lead_corr_matrix_status_converted.png")

# %%
plt.subplots(figsize=(16,16))

corr = df[other_cols + converted].corr()
heatmap = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu")
heatmap.figure.savefig("lead_corr_matrix_other_converted.png")
